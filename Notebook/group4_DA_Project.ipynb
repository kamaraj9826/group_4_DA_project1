# %% [markdown]
# ## Omnichannel Retail Sales and Inventory Analytics

# %% [markdown]
# ##### Week 1: Data Collection, Environment Setup, and Initial Cleaning
# The inaugural week demands the establishment of the foundational infrastructure. Interns must
# initiate the GitHub repository, configuring it to track their Jupyter Notebooks and SQL scripts.
# The intern will import the raw retail dataset into Python/Excel to begin the Data Cleaning phase.
# Tasks include identifying and handling NULL values, removing duplicate records, standardizing
# date/time formats, and validating data types across all columns.

# %% [markdown]
# # What we have to do for this week
#
# 1. Github repo
# 2. Collect dataset
# 3. import the dataset into python / excel
# 4. Data cleaning
# 5. Data Validation

# %% [markdown]
# ### Importing library & dataset

# %%
# importing numpy & pandas

import numpy as np
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# ### Initial Data Exploration

# %%
# read a file
raw_data = pd.read_csv('/content/sample_data/retail_store_inventory.csv')
print(raw_data)
# Out:
#              Date Store ID Product ID     Category Region  Inventory Level  \
# 0      01-01-2022     S001      P0001    Groceries  North              231
# 1      01-01-2022     S001      P0002         Toys  South              204
# 2      01-01-2022     S001      P0003         Toys   West              102
# 3      01-01-2022     S001      P0004         Toys  North              469
# 4      01-01-2022     S001      P0005  Electronics   East              166
# ...           ...      ...        ...          ...    ...              ...
# 73095  01-01-2024     S005      P0016    Furniture   East               96
# 73096  01-01-2024     S005      P0017         Toys  North              313
# 73097  01-01-2024     S005      P0018     Clothing   West              278
# 73098  01-01-2024     S005      P0019         Toys   East              374
# 73099  01-01-2024     S005      P0020    Groceries   East              117
#
# ...

# %%
raw_data.head()
# Out:
#          Date Store ID Product ID     Category Region  Inventory Level  \
# 0  01-01-2022     S001      P0001    Groceries  North              231
# 1  01-01-2022     S001      P0002         Toys  South              204
# 2  01-01-2022     S001      P0003         Toys   West              102
# 3  01-01-2022     S001      P0004         Toys  North              469
# 4  01-01-2022     S001      P0005  Electronics   East              166
#
#    Units Sold  Units Ordered  Demand Forecast  Price  Discount  \
# 0         127             55           135.47  33.50        20
# 1         150             66           144.04  63.01        20
# 2          65             51            74.02  27.99        10
# 3          61            164            62.18  32.72        10
# 4          14            135             9.26  73.64         0
#
#   Weather Condition  Holiday/Promotion  Competitor Pricing Seasonality
# 0             Rainy                  0               29.69      Autumn
# ...

# %%
raw_data.tail()
# Out:
#              Date Store ID Product ID   Category Region  Inventory Level  \
# 73095  01-01-2024     S005      P0016  Furniture   East               96
# 73096  01-01-2024     S005      P0017       Toys  North              313
# 73097  01-01-2024     S005      P0018   Clothing   West              278
# 73098  01-01-2024     S005      P0019       Toys   East              374
# 73099  01-01-2024     S005      P0020  Groceries   East              117
#
#        Units Sold  Units Ordered  Demand Forecast  Price  Discount  \
# 73095           8            127            18.46  73.73        20
# 73096          51            101            48.43  82.57        10
# 73097          36            151            39.65  11.11        10
# 73098         264             21           270.52  53.14        20
# 73099           6            165             2.33  78.39        20
#
#       Weather Condition  Holiday/Promotion  Competitor Pricing Seasonality
# ...

# %%
raw_data.columns
# Out:
# Index(['Date', 'Store ID', 'Product ID', 'Category', 'Region',
#        'Inventory Level', 'Units Sold', 'Units Ordered', 'Demand Forecast',
#        'Price', 'Discount', 'Weather Condition', 'Holiday/Promotion',
#        'Competitor Pricing', 'Seasonality'],
#       dtype='object')

# %%
raw_data.dtypes
# Out:
# Date                   object
# Store ID               object
# Product ID             object
# Category               object
# Region                 object
# Inventory Level         int64
# Units Sold              int64
# Units Ordered           int64
# Demand Forecast       float64
# Price                 float64
# Discount                int64
# Weather Condition      object
# Holiday/Promotion       int64
# Competitor Pricing    float64
# Seasonality            object
# dtype: object

# %%
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 73100 entries, 0 to 73099
# Data columns (total 15 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Date                73100 non-null  object
#  1   Store ID            73100 non-null  object
#  2   Product ID          73100 non-null  object
#  3   Category            73100 non-null  object
#  4   Region              73100 non-null  object
#  5   Inventory Level     73100 non-null  int64
#  6   Units Sold          73100 non-null  int64
#  7   Units Ordered       73100 non-null  int64
#  8   Demand Forecast     73100 non-null  float64
#  9   Price               73100 non-null  float64
#  10  Discount            73100 non-null  int64
#  11  Weather Condition   73100 non-null  object
#  12  Holiday/Promotion   73100 non-null  int64
#  13  Competitor Pricing  73100 non-null  float64
#  14  Seasonality         73100 non-null  object
# ...

# %%
# date in object format -> convert into date
raw_data['Date'].dtypes
# Out:
# dtype('O')

# %%
raw_data.shape
# Out:
# (73100, 15)

# %%
raw_data.size
# Out:
# 1096500

# %%
raw_data.describe()
# Out:
#        Inventory Level    Units Sold  Units Ordered  Demand Forecast  \
# count     73100.000000  73100.000000   73100.000000     73100.000000
# mean        274.469877    136.464870     110.004473       141.494720
# std         129.949514    108.919406      52.277448       109.254076
# min          50.000000      0.000000      20.000000        -9.990000
# 25%         162.000000     49.000000      65.000000        53.670000
# 50%         273.000000    107.000000     110.000000       113.015000
# 75%         387.000000    203.000000     155.000000       208.052500
# max         500.000000    499.000000     200.000000       518.550000
#
#               Price      Discount  Holiday/Promotion  Competitor Pricing
# count  73100.000000  73100.000000       73100.000000        73100.000000
# mean      55.135108     10.009508           0.497305           55.146077
# std       26.021945      7.083746           0.499996           26.191408
# ...

# %%
raw_data.sample()
# Out:
#              Date Store ID Product ID   Category Region  Inventory Level  \
# 56923  24-07-2023     S002      P0004  Furniture   West              314
#
#        Units Sold  Units Ordered  Demand Forecast  Price  Discount  \
# 56923          75            195            77.39  71.94        15
#
#       Weather Condition  Holiday/Promotion  Competitor Pricing Seasonality
# 56923             Snowy                  1               73.91      Autumn

# %%
raw_data.nunique()
# Out:
# Date                    731
# Store ID                  5
# Product ID               20
# Category                  5
# Region                    4
# Inventory Level         451
# Units Sold              498
# Units Ordered           181
# Demand Forecast       31608
# Price                  8999
# Discount                  5
# Weather Condition         4
# Holiday/Promotion         2
# Competitor Pricing     9751
# Seasonality               4
# dtype: int64

# %% [markdown]
# ### Data Cleaning

# %% [markdown]
# #### 1.Check null

# %%
raw_data.isnull().sum()
# Out:
# Date                  0
# Store ID              0
# Product ID            0
# Category              0
# Region                0
# Inventory Level       0
# Units Sold            0
# Units Ordered         0
# Demand Forecast       0
# Price                 0
# Discount              0
# Weather Condition     0
# Holiday/Promotion     0
# Competitor Pricing    0
# Seasonality           0
# dtype: int64

# %%
raw_data.dropna(inplace=True)

# %% [markdown]
# #### 2. Check duplicates & remove it

# %%
raw_data.duplicated().sum()
# Out:
# np.int64(0)

# %%
raw_data.drop_duplicates(inplace=True)

# %%
raw_data.shape
# Out:
# (73100, 15)

# %% [markdown]
# ## Download cleaned dataset

# %%
raw_data.to_csv('Cleaned_retail_inventory_data.csv',index=False)

# %%
cleaned_data = pd.read_csv('/content/Cleaned_retail_inventory_data.csv')
cleaned_data.head()
# Out:
#          Date Store ID Product ID     Category Region  Inventory Level  \
# 0  01-01-2022     S001      P0001    Groceries  North              231
# 1  01-01-2022     S001      P0002         Toys  South              204
# 2  01-01-2022     S001      P0003         Toys   West              102
# 3  01-01-2022     S001      P0004         Toys  North              469
# 4  01-01-2022     S001      P0005  Electronics   East              166
#
#    Units Sold  Units Ordered  Demand Forecast  Price  Discount  \
# 0         127             55           135.47  33.50        20
# 1         150             66           144.04  63.01        20
# 2          65             51            74.02  27.99        10
# 3          61            164            62.18  32.72        10
# 4          14            135             9.26  73.64         0
#
#   Weather Condition  Holiday/Promotion  Competitor Pricing Seasonality
# 0             Rainy                  0               29.69      Autumn
# ...
